# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# # Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # import data files
# data file is already uploaded in the same folder

# %%
dataset = pd.read_csv('Salary_Data.csv')
# print(dataset)

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,-1].values

# print(x)
# print(y)

# %% [markdown]
# ## splitting the datasett int training set testing set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test ,Y_train,Y_test = train_test_split(x , y , test_size=1/3 , random_state=1)

# %% [markdown]
# # Training the simple linear regression model on the training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # This method predict the salaries based on X test data but right now for this simple linear regression we are not gonna use it probably in the future we are gonna use it

# %%
y_pred = regressor.predict(X_test)
#not used right now but in the future we can use it to compare with actual values and fild the loss with it

# %% [markdown]
# # Plotting the values

# %%
plt.scatter(X_train , Y_train , color="red")
plt.plot(X_train , regressor.predict(X_train), color="black")
plt.title("Salary VS Experience (Training set)")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(X_test , Y_test, color="red")
plt.plot(X_train, regressor.predict(X_train), color="black")
plt.title("Salary vs experience (Test data)")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()
# /* In simple terms, when you use a simple linear regression model, you are trying to find two key numbers: 'm' and 'c'. The 'm' represents the slope of the line, and the 'c' represents the y-intercept, or where the line crosses the y-axis.

# Here's how it works:

# Training the Model: You feed your model a set of data (training set) with known 'x' and 'y' values.
# Finding 'm' and 'c': The model uses this data to calculate the best 'm' and 'c' that make the line fit the data as closely as possible.
# Making Predictions: Once you have 'm' and 'c', you can use them to predict 'y' for any new 'x' value by plugging 'x' into the formula 
# 𝑦
# =
# 𝑚
# 𝑥
# +
# 𝑐
# y=mx+c.
# Because 'm' and 'c' are set after training, any new 'x' value will give you a 'y' value that falls on this line.*/

# %% [markdown]
# # Thankyou
